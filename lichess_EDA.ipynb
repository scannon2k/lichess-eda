# %% [markdown]
# https://www.kaggle.com/code/brnhurtado/starter-chess-game-dataset-lichess-b7c900fc-7
#
# https://www.365chess.com/eco.php

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# import display, HTML for nicely formatted tables
from IPython.display import display, HTML

# to suppress warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# load the 'matches' dataset from csv
matches = pd.read_csv('matches.csv')

# observe the rows and columns
rows, cols = matches.shape
print(f"There are {rows} rows and {cols} columns")

# view the dataset with head() and shape()
display(matches.head())
display(matches.describe().T)
# Out:
# There are 20058 rows and 16 columns
#          id  rated    created_at  last_move_at  turns victory_status winner  \
# 0  TZJHLljE  False  1.504210e+12  1.504210e+12     13      outoftime  white
# 1  l1NXvwaE   True  1.504130e+12  1.504130e+12     16         resign  black
# 2  mIICvQHh   True  1.504130e+12  1.504130e+12     61           mate  white
# 3  kWKvrqYL   True  1.504110e+12  1.504110e+12     61           mate  white
# 4  9tXo1AUZ   True  1.504030e+12  1.504030e+12     95           mate  white
#
#   increment_code       white_id  white_rating      black_id  black_rating  \
# 0           15+2       bourgris          1500          a-00          1191
# 1           5+10           a-00          1322     skinnerua          1261
# 2           5+10         ischia          1496          a-00          1500
# 3           20+0  daniamurashov          1439  adivanov2009          1454
# 4           30+3      nik221107          1523  adivanov2009          1469
#
# ...

# %%
print(matches.duplicated())

# check for duplicate IDs, users
# check for duplicate moves, would imply duplicate games played
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 20053    False
# 20054    False
# 20055    False
# 20056    False
# 20057    False
# Length: 20058, dtype: bool

# %%
# check for missing values in the dataset
print(matches.isnull().sum())

# print the total missing values
print("\nTotal missing values:", matches.isnull().sum().sum())
# Out:
# id                0
# rated             0
# created_at        0
# last_move_at      0
# turns             0
# victory_status    0
# winner            0
# increment_code    0
# white_id          0
# white_rating      0
# black_id          0
# black_rating      0
# moves             0
# opening_eco       0
# opening_name      0
# opening_ply       0
# dtype: int64
#
# Total missing values: 0
